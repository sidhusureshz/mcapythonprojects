# %%
#1.Create a class Rectangle with private attributes length and width. Overload ‘<’ operator to compare the area of 2 rectangles. 
class Rectangle:
    def __init__(self, l, b):
        self.length = l
        self.breadth = b
        self.area = l * b

    def __lt__(self, other):
        if self.area < other.area:
            print("Rectangle 2 is greater")
        else:
            print("Rectangle 1 is greater")

l1 = int(input("Enter length of rectangle 1: "))
w1 = int(input("Enter width of rectangle 1: "))
l2 = int(input("Enter length of rectangle 2: "))
w2 = int(input("Enter width of rectangle 2: "))

r1 = Rectangle(l1, w1)
r2 = Rectangle(l2, w2)
r1 < r2
# Out:
# Enter length of rectangle 1:  4
# Enter width of rectangle 1:  3
# Enter length of rectangle 2:  6
# Enter width of rectangle 2:  4
# Rectangle 2 is greater

# %%
#2. Create a class Time with private attributes hour, minute and second. Overload ‘+’ operator to find sum of 2 time.
class Time:
    def __init__(self,hour,minute,second):
        self.hour=hour
        self.minute=minute
        self.second=second
    def __add__(self,other):
        return self.hour+other.hour,self.minute+other.minute,self.second+other.second

t1=Time((int(input("Enter the 1st Hour:"))),(int(input("Enter the 1st Minute :"))),(int(input("Enter the 1st Second:"))))
t2=Time((int(input("Enter the 2nd Hour:"))),(int(input("Enter the 2nd Minute :"))),(int(input("Enter the 2nd Second:"))))  
print("sum of 2 time :",t1+t2)
# Out:
# Enter the 1st Hour: 20
# Enter the 1st Minute : 12
# Enter the 1st Second: 33
# Enter the 2nd Hour: 02
# Enter the 2nd Minute : 22
# Enter the 2nd Second: 12
# sum of 2 time : (22, 34, 45)
